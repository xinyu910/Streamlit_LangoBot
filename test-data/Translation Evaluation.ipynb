# %% [markdown]
# ## Section 1 Load the grammar csv

# %%
import openai
import pandas as pd

# %%
# In our application, we provide the option for users to translate the grammar feedback and standard chatbot messages together.
# Thus, we want to reuse the grammar evaluation dataset,
# focuses soely on AI's messgae and the grammar feedback to test our application's transalation performance
# Specifically, we will compute the similarities between GPT's translation with the translation we get from DeepL API using BLEU score

# Merge the "Message" column and "GPT Output" into one "English Text" column for further translation
translation_df = pd.read_csv('GrammarEvaluation.csv')
df = translation_df.copy()
df.rename(columns={"Message": "English Text"}, inplace=True)
translation_df.rename(columns={"GPT Output": "English Text"}, inplace=True)
df = pd.concat([translation_df, df], ignore_index=True)
df = df[["English Text"]]
df
# Out:
#                                           English Text
# 0    Your response is well-constructed and free fro...
# 1    Your response is grammatically correct and eff...
# 2    Your sentence is grammatically correct, and yo...
# 3    Your response is excellent! It's detailed, cle...
# 4    Your sentence is grammatically correct, well d...
# ..                                                 ...
# 155  Nicely done! 😊 Hermione is indeed an iconic ch...
# 156  Well done!⚽️ Now, let's shift gears and practi...
# 157  Well done! 📚 Jolly good! Now, let's use a bit ...
# 158  Fantastic response! 💫 Now, let's focus on desc...
# 159  Well done! 🇯🇵 That's a really nice description...
#
# [160 rows x 1 columns]

# %% [markdown]
# ## Section 2 Use openai API and deepl API for the translation

# %%
from openai import OpenAI
import os
import time
client = OpenAI(
    # This is the default and can be omitted
    api_key='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'
)

# %%
TRANSLATE_PROMPT = """
        Translate the following paragraph to {native_language}:

        """

def translate_openai(native_language, message):

  prompt = TRANSLATE_PROMPT.format(native_language=native_language, message=message)
  time.sleep(2)
  api_response = client.chat.completions.create(
      model="gpt-4",
      messages=[
          {
              "role": "system",
              "content": prompt
          },
          {
              "role": "user",
              "content": message
          }
      ]
  )
  result = api_response.choices[0].message.content
  print(result)
  return(result)

# %%
print(translate_openai('Chinese', 'Hello'))
# Out:
# 你好
# 你好

# %%
import deepl

# Replace with your actual DeepL API key
deepl_api_key = 'a173f71b-52b0-8ecf-c420-5d031ce980b5:fx'

# Create a Translator object
translator = deepl.Translator(deepl_api_key)


def translate_deepl(native_language, message):
  # convert the target language
  if native_language == 'Chinese':
    native_language = 'ZH'
  elif native_language == 'German':
    native_language = 'DE'
  elif native_language == 'French':
    native_language = 'FR'
  elif native_language == 'Spanish':
    native_language = 'ES'

  try:
      result = translator.translate_text(message, target_lang=native_language)
      print(result.text)
      return (result.text)
  except deepl.DeepLException as error:
      print(f"An error occurred: {error}")

# %%
print( translate_deepl('Chinese', 'Hello'))
# Out:
# 您好
# 您好

# %%
# Define languages to test
languages = ['Chinese', 'German', 'French', 'Spanish']

# Add new columns for each translation method and language
for lang in languages:
    df[f'Deepl_Translation_{lang}'] = ''
    df[f'OpenAI_Translation_{lang}'] = ''

# Perform translations and update DataFrame
for index, row in df.iterrows():
    for lang in languages:
        deepl_result = translate_deepl(lang, row['English Text'])
        openai_result = translate_openai(lang, row['English Text'])
        df.at[index, f'Deepl_Translation_{lang}'] = deepl_result
        df.at[index, f'OpenAI_Translation_{lang}'] = openai_result

# Optionally save to new CSV
df.to_csv('translated_sentences.csv', index=False)
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Erreurs identifiées et explications :
# 1. "Je suis heureux" - Il manque le verbe "être". Le verbe correct est "je suis heureux". Nous utilisons "am" avec le pronom "I" au présent du verbe "be" pour exprimer des états, tels que des sentiments ou qui ou ce que sont les gens.
# Exemples : Je suis fatigué. Je suis professeur.
#
# 2. "It is fun book" - L'article indéfini "a" est manquant. L'usage correct est "C'est un livre amusant". L'article "A" s'utilise devant les noms singuliers, dénombrables et non spécifiques.
# Exemple : "J'ai vu un chien dans le parc : J'ai vu un chien dans le parc.
#
# 3. "J'aime" - Le présent simple doit être utilisé ici. La version correcte est "J'aime".
# Exemple : J'aime la pizza.
#
# 4. "dans le livre" - L'article défini "le" est manquant. L'usage correct est "dans le livre". Le terme "le" est utilisé pour désigner quelque chose de spécifique.
# Exemple : Pouvez-vous ouvrir la porte ?
#
# 5. Ce livre fait" - Pour les sujets singuliers à la troisième personne (comme "ce livre"), nous utilisons "fait". La version correcte est "Ce livre fait".
# Exemple : Il fait beaucoup de bruit quand il mange.
#
# 6. Quand j'ai lu" - Nous devons indiquer ce que "j'ai" lu. Vous pouvez dire "quand je l'ai lu".
# Exemple : Je comprends mieux quand je le lis à haute voix.
# Votre réponse est compréhensible mais nous devons corriger la grammaire.
# Voici comment devrait être votre réponse : "Bonjour! Je suis heureux de vous rencontrer. Mon livre préféré est Harry Potter. C'est un livre amusant. J'aime la magie et l'aventure dans le livre. Ce livre me rend heureux quand je le lis."
#
# Erreurs identifiées et explications :
# 1. "I happy" - Le verbe 'suis' est manquant. L'utilisation correcte est 'Je suis heureux'. On utilise 'suis' avec le pronom 'Je' pour le présent du verbe 'être' pour exprimer des états, tels que des sentiments ou qui ou ce que sont les gens.
# Exemples : Je suis fatigué. Je suis un enseignant.
#
# 2. "It is fun book" - L'article indéfini 'un' est manquant. L'utilisation correcte est 'C'est un livre amusant'. 'Un' est utilisé avant les noms singuliers, comptables, non spécifiques.
# Exemple : J'ai vu un chien dans le parc.
#
# 3. "I liking" - Le présent simple doit être utilisé ici. La version correcte est 'J'aime'.
# Exemple : J'aime la pizza.
#
# 4. "in book" - L'article défini 'le' est manquant. L'utilisation correcte est 'dans le livre'. 'Le' est utilisé lorsqu'on fait référence à quelque chose de spécifique.
# Exemple : Peux-tu ouvrir la porte?
#
# 5. "This book make" - Pour les sujets au singulier de la troisième personne (comme 'ce livre'), on utilise 'rend'. La version correcte est 'Ce livre rend'.
# Exemple : Il fait beaucoup de bruit quand il mange.
#
# 6. "when I read" - Nous devons indiquer ce que 'Je' lis. Vous pouvez dire "quand je le lis".
# Exemple : Je le comprends mieux quand je le lis à haute voix.
# Tu respuesta es comprensible, pero vamos a arreglar la gramática.
# Así es como debería ser tu respuesta "¡Hola! Encantado de conocerte. Mi libro favorito es Harry Potter. Es un libro divertido. Me gusta la magia y la aventura del libro. Este libro me hace feliz cuando lo leo".
#
# Errores identificados y explicaciones:
# 1. "I happy" - Falta el verbo 'am'. El uso correcto es 'I am happy'. Usamos 'am' con el pronombre 'I' para el presente del verbo 'be' para expresar estados, como sentimientos o quién o qué son las personas.
# Ejemplos: Estoy cansado. Soy profesor.
#
# 2. "It is fun book" - Falta el artículo indefinido 'a'. El uso correcto es "Es un libro divertido". A' se usa antes de sustantivos singulares, contables e inespecíficos.
# Ejemplo: Vi un perro en el parque.
#
# 3. "I liking" - Aquí debe utilizarse el presente simple. La versión correcta es "I like".
# Ejemplo: Me gusta la pizza.
#
# 4. "in book" - Falta el artículo definido 'the'. El uso correcto es 'en el libro'. Se usa 'The' cuando se refiere a algo específico.
# Ejemplo: ¿Puedes abrir la puerta?
#
# 5. "This book make" - Para sujetos singulares en tercera persona (como 'this book'), usamos 'makes'. La versión correcta es 'This book makes'.
# Ejemplo: Hace mucho ruido cuando come.
#
# 6. "cuando leo" - Hay que indicar lo que "leo". Se puede decir "cuando lo leo".
# Ejemplo: Lo entiendo mejor cuando lo leo en voz alta
# Tu respuesta es comprensible, pero vamos a arreglar la gramática.
# Aquí te dejo la corrección: "¡Hola! Estoy feliz de conocerte. Mi libro favorito es Harry Potter. Es un libro divertido. Me gusta la magia y la aventura en el libro. Este libro me hace feliz cuando lo leo".
#
# Errores identificados y explicaciones:
# 1. "Yo feliz" - Falta el verbo 'estoy'. La forma correcta es 'Estoy feliz'. Utilizamos 'estoy' con el pronombre 'yo' en el presente del verbo 'estar' para expresar estados, tales como sentimientos o qué o quiénes son las personas.
# Ejemplos: Estoy cansado. Soy un profesor.
#
# 2. "Es libro divertido" - Falta el artículo indefinido 'un'. La forma correcta es 'Es un libro divertido'. 'Un' se utiliza antes de sustantivos singulares, contables y no específicos.
# Ejemplo: Vi un perro en el parque.
#
# 3. "Yo gustando" - Aquí deberíamos usar el presente simple. La versión correcta es 'Me gusta'.
# Ejemplo: Me gusta la pizza.
#
# 4. "en libro" - Falta el artículo definido 'el'. La forma correcta es 'en el libro'. 'El' se utiliza cuando nos referimos a algo específico.
# Ejemplo: ¿Puedes abrir la puerta?
#
# 5. "Este libro hacer" - Para sujetos en tercera persona singular (como 'este libro'), usamos 'hace'. La versión correcta es 'Este libro hace'.
# Ejemplo: Él hace mucho ruido cuando come.
#
# 6. "cuando yo leo" - Necesitamos indicar qué es lo que 'yo' leo. Puedes decir "cuando lo leo".
# Ejemplo: Lo entiendo mejor cuando lo leo en voz alta.
# 您的回复有几处语法错误。以下是正确的版本："是的，我重读过一本《哈利-波特》。我最喜欢《阿兹卡班的囚徒》"。
#
# 错误识别和解释：
#
# 1.时态错误："I am re-read "应为 "I have re-read"。
#  - 在这种情况下，我们使用 "I have "指代与现在有关的过去的行为。
# 例如"我读过那本书"。
# 注意："我 "用于表示现在的连续动作。
# 例如："我正在读那本书："我正在读那本书。
#
# 2.叠词用法不正确："我最喜欢 "应为 "我最喜欢......"。
#  - 当您想表达某事物的最高程度时，我们使用 "最"。结构应为 "我最喜欢......"。
# 例如："我最喜欢巧克力"
#
# 3.缺少冠词："Harry Potter book "应为 "a Harry Potter book"。
#  - 当指代单数、非特定项目时，我们在名词前使用 "a"。
# 例如："我有一本书"："我有一本书"。
# 另一方面，当名词是特定的时候，我们使用 "the"。
# 例如"我有一本书，很有趣"。
# 你的回复中有一些语法错误。以下是正确的版本：“是的，我重读过一本哈利·波特的书。我最喜欢的是《阿兹卡班的囚徒》。”
#
# 找出的错误及解释：
#
# 1. 时态错误："我正在重读"应该是"我重读过"。
#  - 在这种情况下，我们用"I have"来指过去完成并对现在有影响的动作。
# 例如：“我读过那本书。”
# 注意："I am"是用来表示现在正在进行的动作。
# 例如：“我正在读那本书。”
#
# 2. 最高级使用不当："我最喜欢"应该是"我最喜欢的是……"
#  - 当你想表达某事物的最高程度时，我们使用“最”。结构应该是"我最喜欢的是……"。
# 例如：“我最喜欢的是巧克力。”
#
# 3. 缺少冠词："哈利·波特的书"应该是"一本哈利·波特的书"。
#  - 当我们提到单数、非特定的物品时，我们在名词前使用“一本”。
# 例如：“我有一本书。”
# 另一方面，当名词是特定的时，我们使用“那本”。
# 例如：“我有的那本书很有趣。”
# Ihre Antwort enthält einige grammatikalische Fehler. Hier ist die richtige Version: "Ja, ich habe ein Harry-Potter-Buch erneut gelesen. Der Gefangene von Askaban hat mir am besten gefallen."
#
# Identifizierte Fehler und Erklärungen:
#
# 1. Falsche Zeitform: "I am re-read" sollte heißen "I have re-read."
#  - Wir verwenden "ich habe" in diesem Zusammenhang, um eine vergangene Handlung zu bezeichnen, die für die Gegenwart von Bedeutung ist.
# Beispiel: "Ich habe dieses Buch gelesen."
# Hinweis: "Ich bin" wird verwendet, um eine kontinuierliche Handlung in der Gegenwart zu bezeichnen.
# Beispiel: "Ich lese gerade dieses Buch."
#
# 2. Falsche Verwendung des Superlativs: "I most like" sollte heißen "I like... the most."
#  - Wenn Sie den höchsten Grad von etwas ausdrücken wollen, verwenden wir "the most". Die Struktur sollte lauten: "I like... the most."
# Beispiel: "Ich mag Schokolade am liebsten."
#
# 3. Fehlender Artikel: "Harry Potter Buch" sollte "ein Harry Potter Buch" heißen.
#  - Wenn wir uns auf einen singulären, unspezifischen Gegenstand beziehen, verwenden wir "a" vor dem Substantiv.
# Beispiel: "Ich habe ein Buch."
# Wenn es sich jedoch um ein spezifisches Substantiv handelt, verwenden wir "the".
# Beispiel: "Das Buch, das ich habe, ist interessant."
# Ihre Antwort hat einige grammatikalische Fehler. Hier ist die korrekte Version: "Ja, ich habe ein Harry Potter-Buch noch einmal gelesen. Am meisten mag ich den Gefangenen von Askaban."
#
# Fehler identifiziert und Erklärungen:
#
# 1. Falsche Zeit: "Ich bin noch einmal gelesen" sollte "Ich habe noch einmal gelesen" sein.
#  - Wir verwenden in diesem Zusammenhang "Ich habe", um auf eine vergangene Handlung zu verweisen, die für die Gegenwart relevant ist.
# Beispiel: "Ich habe dieses Buch gelesen."
# Anmerkung: "Ich bin" wird verwendet, um eine fortlaufende Handlung in der Gegenwart zu bezeichnen.
# Beispiel: "Ich lese dieses Buch."
#
# 2. Falscher Gebrauch des Superlativs: "Ich mag am meisten" sollte "Am meisten mag ich..." sein.
#  - Wenn Sie den höchsten Grad von etwas ausdrücken wollen, verwenden wir "am meisten". Die Struktur sollte "Am meisten mag ich..." sein.
# Beispiel: "Am meisten mag ich Schokolade."
#
# 3. Fehlender Artikel: "Harry Potter Buch" sollte "ein Harry Potter Buch" sein.
#  - Wenn wir uns auf einen singulären, unspezifischen Gegenstand beziehen, verwenden wir "ein" vor dem Substantiv.
# Beispiel: "Ich habe ein Buch."
# Andererseits, wenn das Substantiv spezifisch ist, verwenden wir "das".
# Beispiel: "Das Buch, das ich habe, ist interessant."
# Votre réponse comporte quelques erreurs grammaticales. Voici la version correcte : "Oui, j'ai relu un livre de Harry Potter. C'est le Prisonnier d'Azkaban que je préfère".
#
# Erreurs identifiées et explications :
#
# 1. Temps incorrect : "Je relis" doit être remplacé par "J'ai relu".
#  - Nous utilisons "j'ai" dans ce contexte pour faire référence à une action passée qui a un rapport avec le présent.
# Exemple : "J'ai lu ce livre : "J'ai lu ce livre".
# Note : "Je suis" est utilisé pour indiquer une action continue dans le présent.
# Exemple : "Je suis en train de lire ce livre : "Je suis en train de lire ce livre".
#
# 2. Mauvais usage du superlatif : "J'aime beaucoup" devrait être "J'aime... beaucoup".
#  - Lorsque l'on veut exprimer le degré le plus élevé de quelque chose, on utilise "le plus". La structure devrait être "J'aime... le plus".
# Exemple : "C'est le chocolat que j'aime le plus".
#
# 3. Article manquant : "Le livre de Harry Potter" devrait être "un livre de Harry Potter".
#  - Lorsque l'on parle d'un objet singulier et non spécifique, on utilise "a" devant le nom.
# Exemple : "J'ai un livre" : "J'ai un livre".
# En revanche, lorsque le nom est spécifique, on utilise "le".
# Exemple : "Le livre que j'ai est intéressant".
# Votre réponse contient quelques erreurs grammaticales. Voici la version corrigée : "Oui, j'ai relu un livre de Harry Potter. J'aime le plus le Prisonnier d'Azkaban."
#
# Erreurs identifiées et explications :
#
# 1. Temps incorrect : "Je suis relire" devrait être "J'ai relu".
#  - Nous utilisons "j'ai" dans ce contexte pour faire référence à une action passée qui a de la pertinence pour le présent.
# Exemple : "J'ai lu ce livre."
# Note : "Je suis" est utilisé pour indiquer une action continue dans le présent.
# Exemple : "Je suis en train de lire ce livre."
#
# 2. Utilisation incorrecte du superlatif: "J'aime le plus" devrait être "J'aime... le plus."
#  - Lorsque vous voulez exprimer le plus haut degré de quelque chose, nous utilisons "le plus". La structure devrait être "J'aime... le plus."
# Exemple : "J'aime le plus le chocolat."
#
# 3. Article manquant : "Livre de Harry Potter" devrait être "un livre de Harry Potter."
#  - Lorsque nous faisons référence à un élément singulier et non spécifique, nous utilisons "un" avant le nom.
# Exemple : "J'ai un livre."
# D'un autre côté, lorsque le nom est spécifique, nous utilisons "le".
# Exemple : "Le livre que je possède est intéressant."
# Su respuesta tiene algunos errores gramaticales. Aquí tienes la versión correcta: "Sí, he releído algún libro de Harry Potter. El que más me gusta es El prisionero de Azkaban".
#
# Errores identificados y explicaciones:
#
# 1. Tiempo verbal incorrecto: "Estoy releyendo" debería ser "He releído".
#  - Utilizamos "he" en este contexto para referirnos a una acción pasada que tiene relevancia en el presente.
# Ejemplo: "He leído ese libro".
# Nota: "I am" se utiliza para denotar una acción continua en el presente.
# Ejemplo: "Estoy leyendo ese libro".
#
# 2. Uso incorrecto del superlativo: "Lo que más me gusta" debería ser "Lo que más me gusta".
#  - Cuando se quiere expresar el grado más alto de algo, se utiliza "the most". La estructura debería ser "Me gusta... lo más".
# Ejemplo: "El chocolate es lo que más me gusta".
#
# 3. Falta el artículo: "El libro de Harry Potter" debería ser "un libro de Harry Potter".
#  - Cuando nos referimos a un artículo singular, no específico, usamos "a" antes del sustantivo.
# Ejemplo: "Tengo un libro".
# En cambio, cuando el sustantivo es específico, utilizamos "the".
# Ejemplo: "El libro que tengo es interesante".
# Tu respuesta tiene algunos errores gramaticales. Aquí está la versión correcta: "Sí, he releído un libro de Harry Potter. Me gusta más el Prisionero de Azkaban."
#
# Errores identificados y explicaciones:
#
# 1. Tiempo verbal incorrecto: "Estoy releyendo" debería ser "he releído".
#  - Usamos "he" en este contexto para referirnos a una acción pasada que tiene relevancia en el presente.
# Ejemplo: "He leído ese libro".
# Nota: "Estoy" se usa para denotar una acción continua en el presente.
# Ejemplo: "Estoy leyendo ese libro."
#
# 2. Uso incorrecto del superlativo: "Me gusta más" debería ser "Me gusta ... el más".
#  - Cuando quieres expresar el grado más alto de algo, usamos "el más". La estructura debería ser "Me gusta ... el más".
# Ejemplo: "Me gusta el chocolate el más."
#
# 3. Artículo faltante: "libro de Harry Potter" debería ser "un libro de Harry Potter".
#  - Cuando nos referimos a un artículo singular, no específico, usamos "un" antes del sustantivo.
# Ejemplo: "Tengo un libro".
# Por otro lado, cuando el sustantivo es específico, usamos "el".
# Ejemplo: "El libro que tengo es interesante."
# 你的回答基本清晰有效。但是，还需要修改一些语法，使之更加完美：
# 1."Sirius Black is very kind and brave man." 应该是 "小天狼星布莱克是一个非常善良勇敢的人"。此处 "非常善良勇敢的人 "前缺少不定冠词 "a"。
# 2."他总是帮助哈利 "应为 "他总是帮助哈利"。这里的正确形式是第三人称单数形式 "hels"。
# 3."He was in prison because people think he is bad, but he is not." 应该是 "He was in prison because people thought he was bad, but he is not."。这里应该用过去式 "认为 "而不是 "认为"，因为上下文中的动作发生在过去。
#
# 错误和解释：
# 1.缺少不定冠词 "a"：不定冠词 "a "用于描述或定义名词的短语前。
# 2.第三人称单数中使用不正确的形式：第三人称单数的现在时态动词需要以-s 或-es 结尾。
# 3.时态不正确："Think "是现在时态，"thought "是过去时态。指过去的事情时用 "想"。
#
# 已纠正的句子：
# 1."小天狼星布莱克是一个非常善良勇敢的人"。
# 2."他总是帮助哈利
# 3."他被关进监狱 是因为人们认为他是坏人 但他不是"
#
# 你的答案很好地考虑了问题，继续练习语法！
# 你的回答大部分都很清楚且有效。然而，为了使其更为完美，有些语法需要进行纠正:
# 1. "Sirius Black is very kind and brave man." 应为 "Sirius Black is a very kind and brave man." 这里，在"very kind and brave man."之前缺少不定冠词"a"。
# 2. "He is always help Harry." 应为 "He always helps Harry." 在这里，正确的形式应该使用第三人称单数形式的"helps"。
# 3. "He was in prison because people think he is bad, but he is not." 应为 "He was in prison because people thought he was bad, but he is not." 这里，我们应该使用过去式"thought"而不是"think"，因为情境中的行为是在过去进行的。
#
# 错误和解释：
# 1. 缺少不定冠词"a"：在描述或定义名词的短语之前，我们需要使用不定冠词"a"。
# 2. 第三人称单数形式的使用错误：在现在时态中，第三人称单数形式的动词需要加上-s或者-es。
# 3. 时态错误："Think"是现在时态，而"thought"是过去时态。当提及过去的事件时，我们要使用"thought"。
#
# 改正后的句子：
# 1. "Sirius Black is a very kind and brave man."
# 2. "He always helps Harry."
# 3. "He was in prison because people thought he was bad, but he is not."
#
# 你的回答很好的考虑到了问题，继续加强语法的练习吧！
# Ihre Antwort war größtenteils klar und effektiv. Es sind jedoch einige grammatikalische Korrekturen erforderlich, um sie perfekt zu machen:
# 1. "Sirius Black ist ein sehr freundlicher und tapferer Mann." sollte heißen "Sirius Black ist ein sehr freundlicher und tapferer Mann." Hier fehlt ein unbestimmter Artikel "a" vor "very kind and brave man".
# 2. "Er hilft Harry immer." sollte heißen: "Er hilft Harry immer." Die richtige Form ist hier die dritte Person Singular "hilft".
# 3. "Er war im Gefängnis, weil die Leute dachten, er sei schlecht, aber er ist es nicht." sollte heißen: "Er war im Gefängnis, weil die Leute dachten, er sei schlecht, aber er ist es nicht." Wir sollten hier die Vergangenheitsform "thought" anstelle von "think" verwenden, da die Handlung im Kontext in der Vergangenheit stattfand.
#
# Fehler und Erklärungen:
# 1. Fehlender unbestimmter Artikel "a": Der unbestimmte Artikel "a" wird vor Sätzen verwendet, die ein Substantiv beschreiben oder definieren.
# 2. Verwendung der falschen Form in der dritten Person Singular: Die dritte Person Singular erfordert eine -s oder -es Endung für die Verben im Präsens.
# 3. Falsche Zeitform: "Think" steht im Präsens und "thought" in der Vergangenheit. Verwenden Sie "thought", wenn Sie sich auf vergangene Ereignisse beziehen.
#
# Korrigierte Sätze:
# 1. "Sirius Black ist ein sehr freundlicher und mutiger Mann."
# 2. "Er hilft Harry immer."
# 3. "Er war im Gefängnis, weil die Leute dachten, er sei böse, aber er ist es nicht."
#
# Deine Antwort hat der Frage gut Rechnung getragen, übe weiter an deiner Grammatik!
# Ihre Antwort war größtenteils klar und effektiv. Es sind jedoch einige Grammatikkorrekturen erforderlich, damit sie perfekt ist:
# 1. "Sirius Black ist sehr freundlich und mutiger Mann." sollte "Sirius Black ist ein sehr freundlicher und mutiger Mann." sein. Hier fehlt ein unbestimmter Artikel "ein" vor "sehr freundlicher und mutiger Mann".
# 2. "Er hilft immer Harry." sollte "Er hilft Harry immer." sein. Die korrekte Form hier ist die dritte Person Singular Form "hilft".
# 3. "Er war im Gefängnis, weil die Leute denken, er sei schlecht, aber er ist es nicht." sollte "Er war im Gefängnis, weil die Leute dachten, er sei schlecht, aber er ist es nicht." Wir sollten hier "dachten" anstelle von "denken" verwenden, da die Handlung in diesem Kontext in der Vergangenheit liegt.
#
# Fehler und Erklärungen:
# 1. Fehlender unbestimmter Artikel "ein": Der unbestimmte Artikel "ein" wird vor Phrasen verwendet, die ein Substantiv beschreiben oder definieren.
# 2. Verwendung der falschen Form im Singular der dritten Person: Die dritte Person Singular erfordert im Präsens ein -s oder -es Ende für die Verben.
# 3. Falsche Zeitform: "Denken" ist im Präsens und "dachten" im Präteritum. Verwenden Sie "dachten", wenn Sie auf vergangene Ereignisse Bezug nehmen.
#
# Korrigierte Sätze:
# 1. "Sirius Black ist ein sehr freundlicher und mutiger Mann."
# 2. "Er hilft Harry immer."
# 3. "Er war im Gefängnis, weil die Leute dachten, er sei schlecht, aber er ist es nicht."
#
# Ihre Antwort hat die Frage gut berücksichtigt, üben Sie weiter an Ihrer Grammatik!
# Votre réponse était en grande partie claire et efficace. Cependant, quelques corrections grammaticales sont nécessaires pour qu'elle soit parfaite :
# 1. "Sirius Black est un homme très gentil et très courageux" devrait être "Sirius Black est un homme très gentil et très courageux". Ici, il manque l'article indéfini "a" avant "très gentil et courageux".
# 2. "Il aide toujours Harry" devrait être "Il aide toujours Harry". La forme correcte ici est la troisième personne du singulier "aide".
# 3. "Il était en prison parce que les gens pensent qu'il est mauvais, mais il ne l'est pas" devrait être "Il était en prison parce que les gens pensent qu'il est mauvais, mais il ne l'est pas". Nous devrions utiliser le passé "pensait" au lieu de "pense" ici parce que l'action dans le contexte a eu lieu dans le passé.
#
# Erreurs et explications :
# 1. Absence de l'article indéfini "a" : L'article indéfini "a" est utilisé avant les phrases qui décrivent ou définissent un nom.
# 2. Utilisation d'une forme incorrecte à la troisième personne du singulier : La troisième personne du singulier nécessite une terminaison en -s ou -es pour les verbes au présent.
# 3. Temps incorrect : "Think" est au présent et "thought" est au passé. Utilisez "pensée" lorsque vous vous référez à des événements passés.
#
# Phrases corrigées :
# 1. "Sirius Black est un homme très gentil et très courageux.
# 2. "Il aide toujours Harry".
# 3. "Il était en prison parce que les gens pensaient qu'il était mauvais, mais il ne l'est pas."
#
# Votre réponse a bien pris en compte la question, continuez à vous entraîner sur votre grammaire !
# Votre réponse était en grande partie claire et efficace. Cependant, quelques corrections grammaticales sont nécessaires pour qu'elle soit parfaite :
# 1. "Sirius Black is very kind and brave man." devrait être "Sirius Black is a very kind and brave man." Ici, un article indéfini "a" manque avant "very kind and brave man."
# 2. "He is always help Harry." devrait être "He always helps Harry." La forme correcte ici est la troisième personne du singulier "helps."
# 3. "He was in prison because people think he is bad, but he is not." devrait être "He was in prison because people thought he was bad, but he is not." Nous devrions utiliser le passé "thought" au lieu de "think" ici car l'action en contexte a eu lieu dans le passé.
#
# Erreurs et explications :
# 1. Article indéfini "a" manquant : L'article indéfini "a" est utilisé avant les phrases qui décrivent ou définissent un nom.
# 2. Utilisation de la forme incorrecte à la troisième personne du singulier : La troisième personne du singulier nécessite une terminaison en -s ou -es pour les verbes au présent.
# 3. Temps incorrect : "Think" est au présent et "thought" est au passé. Utilisez "thought" lorsque vous vous référez à des événements passés.
#
# Phrases corrigées :
# 1. "Sirius Black est un homme très gentil et courageux."
# 2. "Il aide toujours Harry."
# 3. "Il était en prison parce que les gens pensaient qu'il était méchant, mais ce n'est pas le cas."
#
# Votre réponse a bien pris en compte la question, continuez à vous exercer sur votre grammaire!
# Su respuesta fue en su mayor parte clara y eficaz. Sin embargo, son necesarias algunas correcciones gramaticales para que sea perfecta:
# 1. "Sirius Black es un hombre muy amable y valiente" debería ser "Sirius Black es un hombre muy amable y valiente". Aquí falta un artículo indefinido "a" antes de "hombre muy amable y valiente".
# 2. "Siempre ayuda a Harry" debería ser "Siempre ayuda a Harry". La forma correcta aquí es la tercera persona del singular "helps".
# 3. "Estuvo en la cárcel porque la gente piensa que es malo, pero no lo es". debería ser "Estuvo en la cárcel porque la gente pensaba que era malo, pero no lo es". Aquí deberíamos usar el tiempo pasado "pensó" en lugar de "piensa" porque la acción en el contexto tuvo lugar en el pasado.
#
# Errores y explicaciones:
# 1. Falta el artículo indefinido "a": El artículo indefinido "a" se usa antes de frases que describen o definen un sustantivo.
# 2. 2. Uso de la forma incorrecta en tercera persona del singular: La tercera persona del singular requiere una terminación -s o -es para los verbos en presente.
# 3. Tiempo verbal incorrecto: "Think" está en presente y "thought" está en pasado. Utilice "thought" cuando se refiera a hechos pasados.
#
# Frases corregidas:
# 1. "Sirius Black es un hombre muy amable y valiente".
# 2. "Siempre ayuda a Harry".
# 3. "Estuvo en la cárcel porque la gente pensaba que era malo, pero no lo es".
#
# Tu respuesta ha tenido bien en cuenta la pregunta, ¡sigue practicando con la gramática!
# Tu respuesta fue principalmente clara y efectiva. Sin embargo, se necesitan algunas correcciones gramaticales para que sea perfecta:
# 1. "Sirius Black es muy amable y valiente hombre." debería ser "Sirius Black es un hombre muy amable y valiente." Aquí, falta el artículo indefinido "un" antes de "hombre muy amable y valiente".
# 2. "Él siempre ayuda a Harry." debe ser "Él siempre ayuda a Harry." La forma correcta aquí es la tercera persona del singular "ayuda".
# 3. "Estaba en prisión porque la gente piensa que es malo, pero no lo es." debería ser "Estaba en prisión porque la gente pensaba que era malo, pero no lo es." Deberíamos usar el pasado "pensaba" en lugar de "piensa" aquí porque la acción en contexto ocurrió en el pasado.
#
# Errores y explicaciones:
# 1. Falta el artículo indefinido "un": Se usa el artículo indefinido "un" antes de las frases que describen o definen un sustantivo.
# 2. Uso incorrecto de la forma en tercera persona del singular: La tercera persona singular requiere un final -s o -es para los verbos en tiempo presente.
# 3. Tiempo incorrecto: "Piensa" está en tiempo presente y "pensaba" en tiempo pasado. Usa "pensaba" cuando te refieres a eventos pasados.
#
# Frases corregidas:
# 1. "Sirius Black es un hombre muy amable y valiente."
# 2. "Él siempre ayuda a Harry."
# 3. "Estaba en prisión porque la gente pensaba que era malo, pero no lo es."
#
# Tu respuesta tiene en cuenta bien la pregunta, ¡sigue practicando tu gramática!
# 您对霍格沃茨的描述丰富多彩，充满细节！但有几处语法和拼写错误。更正后的版本应该是"霍格沃茨是一所非常大的魔法学校。它有很多房间，其中一些是秘密的。学校里有魔法物品、幽灵和魔法生物。有学生宿舍和一个大餐厅。它非常美丽和神秘。它可能很危险，但也是学生们学习魔法和交朋友的地方。"
#
# 错误识别与解释：
# 1.拼写错误：正确的拼写是 "mysterious"，而不是 "misterious"。
#
# 2.在 "some is secret "和 "there is dorms for students "中，"is "的用法不正确。
#     - 应使用 "are "而不是 "is"，因为这两个句子指的是几件事（房间和宿舍）。
#     - 更正后的例子是 "有些房间是秘密的 "和 "有学生宿舍"。
#
# 3.3. "can be dangerous "中的 "can "使用不当。
#     - 应使用 "它可以 "来说明 "它"（霍格沃茨）可能很危险，而不是 "可以"。
#
# 继续练习！你每天都在进步！
# 你对霍格沃兹的描述是如此的丰富多彩和富有细节！然而，里面有一些小的语法和拼写错误。改正后的版本应该是：“霍格沃茨是一个非常大的魔法学校。它有很多房间，其中一些是秘密的。它有魔法物品、幽灵和魔法生物。有供学生住的宿舍和一个大的食堂。它非常美丽且神秘。它可能很危险，但它也是学生们学习魔法和结交朋友的地方。”
#
# 发现的错误和解释：
# 1. 拼写错误：正确的拼写应该是'mysterious'，而不是'misterious'。
#
# 2. "is" 的使用不正确，例如"some is secret" 和 "there is dorms for students."
#    - 你应该使用 "are" 而不是"is" ，因为这些句子指的是几个事物（房间和宿舍）。
#    - 纠正后的例子应该是 "Some rooms are secret," 和 "There are dorms for students."
#
# 3. "can" 的使用不正确，如"can be dangerous."
#    - 你应该使用 "it can" 而不是"can" ，以指出'它'（霍格沃茨）可能是危险的。
#
# 继续努力！你每天都在进步！
# Ihre Beschreibung von Hogwarts ist farbenfroh und voller Details! Allerdings gibt es ein paar kleinere Grammatik- und Rechtschreibfehler. Die korrigierte Version sollte lauten: "Hogwarts ist eine sehr große magische Schule. Sie hat sehr viele Räume, von denen einige geheim sind. Es gibt dort magische Gegenstände, Geister und magische Kreaturen. Es gibt Schlafsäle für Schüler und einen großen Speisesaal. Sie ist sehr schön und geheimnisvoll. Es kann gefährlich sein, aber es ist auch ein Ort, an dem die Schüler Magie lernen und Freunde finden."
#
# Identifizierte Fehler und Erklärungen:
# 1. Rechtschreibfehler: Die richtige Schreibweise ist "mysteriös", nicht "misteriös".
#
# 2. Falsche Verwendung von "ist" in "some is secret" und "there is dorms for students".
#     - Anstelle von "ist" sollten Sie "sind" verwenden, da sich die Sätze auf mehrere Dinge beziehen (Zimmer und Wohnheime).
#     - Ein korrigiertes Beispiel wäre "Some rooms are secret" und "There are dorms for students".
#
# 3. Falsche Verwendung von "kann" in "kann gefährlich sein".
#     - Anstelle von "kann" sollten Sie "es kann" verwenden, um zu verdeutlichen, dass "es" (Hogwarts) gefährlich sein kann.
#
# Übe weiter! Du wirst jeden Tag besser!
# Ihre Beschreibung von Hogwarts ist farbenfroh und voller Details! Es gibt jedoch einige kleinere grammatikalische und Rechtschreibfehler. Die korrigierte Version sollte lauten: "Hogwarts ist eine sehr große magische Schule. Sie hat viele Räume, von denen einige geheim sind. Es gibt magische Objekte, Geister und magische Kreaturen. Es gibt Schlafsäle für die Schüler und eine große Speisehalle. Sie ist sehr schön und geheimnisvoll. Es kann gefährlich sein, aber es ist auch ein Ort, an dem die Schüler Magie lernen und Freunde finden."
#
# Identifizierte Fehler und Erklärungen:
# 1. Rechtschreibfehler: Die richtige Schreibweise ist 'geheimnisvoll', nicht 'misterious'.
#
# 2. Falsche Verwendung von "ist" in "etwas ist geheim" und "es gibt Schlafsäle für Studenten".
#     - Anstelle von "ist", sollten Sie "sind" verwenden, weil sich die Sätze auf mehrere Dinge beziehen (Räume und Schlafsäle).
#     - Ein korrigiertes Beispiel wäre "Einige Räume sind geheim", und "Es gibt Schlafsäle für die Schüler."
#
# 3. Falsche Verwendung von "können" in "kann gefährlich sein".
#     - Anstelle von "können", sollten Sie "es kann" verwenden, um zu spezifizieren, dass 'es' (Hogwarts) gefährlich sein kann.
#
# Bleiben Sie dran! Sie verbessern sich jeden Tag!
# Votre description de Poudlard est colorée et pleine de détails ! Cependant, il y a quelques petites fautes de grammaire et d'orthographe. La version corrigée devrait être : "Poudlard est une très grande école de magie. Elle possède de nombreuses salles, dont certaines sont secrètes. On y trouve des objets magiques, des fantômes et des créatures magiques. Il y a des dortoirs pour les élèves et un grand réfectoire. C'est très beau et très mystérieux. Il peut être dangereux, mais c'est aussi un endroit où les élèves apprennent la magie et se font des amis.
#
# Erreurs identifiées et explications :
# 1. Erreur d'orthographe : L'orthographe correcte est "mystérieux" et non "misterious".
#
# 2. Utilisation incorrecte de "is" dans "some is secret" et "there is dorms for students".
#     - Au lieu de "est", vous devriez utiliser "sont" car les phrases font référence à plusieurs choses (les chambres et les dortoirs).
#     - Un exemple corrigé serait "Certaines chambres sont secrètes" et "Il y a des dortoirs pour les étudiants".
#
# 3. Utilisation incorrecte de "peut" dans "peut être dangereux".
#     - Au lieu de "peut", vous devriez utiliser "il peut" pour préciser que "il" (Poudlard) peut être dangereux.
#
# Continuez à vous entraîner ! Vous vous améliorez de jour en jour !
# Votre description de Poudlard est colorée et pleine de détails ! Cependant, il y a quelques petites erreurs grammaticales et d'orthographe. La version corrigée devrait être : "Poudlard est une très grande école magique. Elle a beaucoup de pièces, certaines d'entre elles sont secrètes. Elle possède des objets magiques, des fantômes et des créatures magiques. Il y a des dortoirs pour les élèves et une grande salle à manger. Elle est très belle et mystérieuse. Elle peut être dangereuse, mais c'est aussi un endroit où les élèves apprennent la magie et se font des amis."
#
# Erreurs identifiées et explications :
# 1. Erreur d'orthographe : L'orthographe correcte est 'mystérieuse', pas 'misterieuse'.
#
# 2. Usage incorrect de "est" dans "certaines est secrètes" et "il y a des dortoirs pour les élèves".
#     - Au lieu de "est", vous devriez utiliser "sont" parce que les phrases se réfèrent à plusieurs choses (pièces et dortoirs).
#     - Un exemple corrigé serait "Certaines pièces sont secrètes," et "Il y a des dortoirs pour les élèves."
#
# 3. Utilisation incorrecte de "peut" dans "peut être dangereuse."
#     - Au lieu de "peut", vous devriez utiliser "elle peut" pour spécifier que 'elle' (Poudlard) peut être dangereuse.
#
# Continuez à vous entraîner ! Vous vous améliorez chaque jour !
# Tu descripción de Hogwarts es colorida y llena de detalles. Sin embargo, hay algunos pequeños errores gramaticales y ortográficos. La versión corregida debería ser: "Hogwarts es un colegio mágico muy grande. Tiene muchas habitaciones, algunas de las cuales son secretas. Tiene objetos mágicos, fantasmas y criaturas mágicas. Hay dormitorios para los alumnos y un gran comedor. Es muy bonita y misteriosa. Puede ser peligroso, pero también es un lugar donde los estudiantes aprenden magia y hacen amigos".
#
# Errores identificados y explicaciones:
# 1. 1. Error ortográfico: La ortografía correcta es 'misterioso', no 'misterioso'.
#
# 2. Uso incorrecto de "es" en "algo es secreto" y "hay dormitorios para estudiantes".
#     - En lugar de "es", debes usar "son" porque las frases se refieren a varias cosas (habitaciones y dormitorios).
#     - Un ejemplo corregido sería "Algunas habitaciones son secretas" y "Hay dormitorios para estudiantes".
#
# 3. Uso incorrecto de "puede" en "puede ser peligroso".
#     - En lugar de "puede", deberías usar "puede" para especificar que "eso" (Hogwarts) puede ser peligroso.
#
# ¡Sigue practicando! ¡Estás mejorando cada día!
# ¡Tu descripción de Hogwarts es colorida y llena de detalles! Sin embargo, hay algunos errores gramaticales y ortográficos menores. La versión corregida debería ser: "Hogwarts es una escuela mágica muy grande. Tiene muchas habitaciones, algunas de las cuales son secretas. Tiene objetos mágicos, fantasmas y criaturas mágicas. Hay dormitorios para los estudiantes y un gran comedor. Es muy bonito y misterioso. Puede ser peligroso, pero también es un lugar donde los estudiantes aprenden magia y hacen amigos."
#
# Errores identificados y explicaciones:
# 1. Error ortográfico: La ortografía correcta es 'misterioso', no 'misterioso'.
#
# 2. Uso incorrecto de "es" en "algunas son secretos" y "hay dormitorios para los estudiantes."
#    - En lugar de "es", deberías usar "son" porque las frases se refieren a varias cosas (habitaciones y dormitorios).
#    - Un ejemplo corregido sería "Algunas habitaciones son secretas" y "Hay dormitorios para los estudiantes."
#
# 3. Uso incorrecto de "puede" en "puede ser peligroso."
#    - En lugar de "puede", deberías usar "puede ser" para especificar que 'es' (Hogwarts) puede ser peligroso.
#
# ¡Sigue practicando! ¡Mejoras cada día!
# 您的句子有几处拼写和语法错误。以下是更正后的版本："是的，我计划阅读更多 J.K. 罗琳的书。我非常喜欢《哈利-波特》。读完之后，我想读读《杜鹃的呼唤》。这本书比较成熟，但我喜欢悬疑，所以我觉得会很适合我！"
#
# 发现的错误及其解释：
# 1.拼写错误："Rowlling "应拼成 "Rowling"，"mistery "应拼成 "mystery"。
#
# 2.介词的使用：正确的短语应该是 "books by J.K. Rowling"，而不是 "books of J.K Rowling"。我们使用介词 "by "来表示一本书的作者。
# 正确用法的例子是 "我正在读斯蒂芬-金的一本书"。
#
# 3.动词形式不正确：在 "after "之后，动词形式应该是 "finishing"，而不是 "finish"。
# 要解决这个问题，动词需要使用-ing 形式，因此句子应该是这样的："读完之后，我想读一读《杜鹃的呼唤》"。
#
# 4.选词："成人 "一词一般指长大成人的人，而 "成熟 "一词更适合用来形容为成人或大人准备的内容。
# 例如"这部小说由于主题复杂，适合成熟读者阅读"。
#
# 不过，你已经有效地回答了问题，你未来的阅读计划听起来也很不错！继续努力
# 你的句子中有一些小的拼写和语法错误。这是改正后的版本："是的，我打算再读一些J.K.罗琳的书。我非常喜欢哈利·波特。看完之后，我想读'布谷鸟的叫声'。这本书更成熟，但我喜欢悬疑类的书，所以我认为这对我来说会是个不错的选择。"
#
# 发现的错误和其解释：
# 1. 拼写错误：“Rowlling”应拼写为“Rowling”，“mistery”应拼写为“mystery”。
# 2. 介词的使用：“J.K.罗琳的书”应该说“J.K．罗琳写的书”，而不是“J.K．罗琳的书”。我们用介词'by'来表示一本书的作者。
# 例如：“我正在读斯蒂芬·金的一本书。”
# 3. 动词形式错误：在“after”之后，动词形式应为“finishing”，而不是“finish”。
# 修正这个错误需要用到-ing的动词形式，所以句子应该是这样的：“看完之后，我想读'布谷鸟的叫声'。”
# 4. 词语选择：“adult”一词通常指成年人，而“mature”是描述为成人或成年人准备的内容更合适的词。
# 例如：“这本小说因其复杂的主题，而广受成熟观众的喜爱。”
#
# 然而，你有效地回答了问题，而且你的未来阅读计划听起来非常棒！继续努力。
# Ihr Satz enthält einige kleine Rechtschreib- und Grammatikfehler. Hier ist die korrigierte Fassung: "Ja, ich habe vor, weitere Bücher von J.K. Rowling zu lesen. Harry Potter gefällt mir sehr gut. Wenn ich damit fertig bin, möchte ich 'The Cuckoo's Calling' lesen. Es ist etwas erwachsener, aber ich mag Krimis, also denke ich, dass es gut für mich sein wird!"
#
# Identifizierte Fehler und ihre Erklärungen:
# 1. Rechtschreibfehler: "Rowling" sollte als "Rowling" geschrieben werden und "mistery" sollte als "mystery" geschrieben werden.
#
# 2. Verwendung der Präposition: Die korrekte Formulierung wäre "Bücher von J.K. Rowling", nicht "Bücher von J.K Rowling". Wir verwenden die Präposition "von", um den Autor eines Buches anzugeben.
# Ein Beispiel für die korrekte Verwendung ist "Ich lese ein Buch von Stephen King".
#
# 3. Falsche Verbform: Nach "after" sollte die Verbform "finishing" und nicht "finish" lauten.
# Um dies zu korrigieren, muss das Verb in der -ing-Form stehen, so dass der Satz wie folgt aussehen sollte: "Nachdem ich fertig bin, möchte ich 'The Cuckoo's Calling' lesen."
#
# 4. Wortwahl: Das Wort "erwachsen" bezieht sich im Allgemeinen auf eine erwachsene Person, während "reif" ein geeigneteres Wort ist, um Inhalte zu beschreiben, die für Erwachsene oder Erwachsene bestimmt sind.
# Beispiel: "Der Roman ist aufgrund seiner komplexen Themen für ein erwachsenes Publikum bestimmt."
#
# Wie auch immer, Sie haben die Frage gut beantwortet und Ihre zukünftigen Lesepläne klingen großartig! Machen Sie weiter so.
# Ihr Satz hat einige kleinere Rechtschreib- und Grammatikfehler. Hier ist die korrigierte Version: "Ja, ich habe vor, mehr Bücher von J.K. Rowling zu lesen. Ich mag Harry Potter sehr. Nachdem ich fertig bin, möchte ich 'The Cuckoo's Calling' lesen. Es ist reifer, aber ich mag Mystery, also denke ich, dass es gut für mich sein wird!"
#
# Identifizierte Fehler und ihre Erklärungen:
# 1. Rechtschreibfehler: "Rowlling" sollte als "Rowling" und "mistery" als "mystery" geschrieben werden.
#
# 2. Gebrauch von Präpositionen: Die korrekte Phrase wäre "Bücher von J.K. Rowling", nicht "Bücher von J.K. Rowling". Wir verwenden die Präposition 'von', um den Autor eines Buches anzugeben.
# Ein Beispiel für die korrekte Verwendung ist "Ich lese ein Buch von Stephen King."
#
# 3. Falsche Verbform: Nach 'nachdem' sollte die Verbform 'fertig' nicht 'beendet' sein. Um dies zu korrigieren, muss das Verb in der Form "fertig sein", so sollte der Satz aussehen: "Nachdem ich fertig bin, möchte ich 'The Cuckoo's Calling' lesen."
#
# 4. Wortwahl: Das Wort "erwachsen" bezieht sich im Allgemeinen auf eine Person, die erwachsen ist, während "reif" ein geeigneteres Wort ist, um Inhalte zu beschreiben, die für Erwachsene bestimmt sind.
# Beispiel: "Der Roman ist aufgrund seiner komplexen Themen für ein reifes Publikum gedacht."
#
# Sie haben jedoch die Frage effektiv beantwortet und Ihre zukünftigen Lesepläne klingen großartig! Machen Sie weiter so.
# Votre phrase comporte quelques petites fautes d'orthographe et de grammaire. Voici la version corrigée : "Oui, j'ai l'intention de lire d'autres livres de J.K. Rowling. J'aime beaucoup Harry Potter. Quand je l'aurai terminé, j'aimerais lire "L'appel du coucou". C'est un livre plus mature, mais j'aime les mystères, alors je pense qu'il me conviendra !
#
# Erreurs identifiées et leurs explications :
# 1. Erreurs d'orthographe : "Rowlling" doit s'écrire "Rowling" et "mistery" doit s'écrire "mystery".
#
# 2. Utilisation de la préposition : La phrase correcte serait "les livres de J.K. Rowling", et non "les livres de J.K. Rowling". Nous utilisons la préposition "par" pour indiquer l'auteur d'un livre.
# Voici un exemple d'utilisation correcte : "Je suis en train de lire un livre de Stephen King".
#
# 3. Forme verbale incorrecte : Après "après", la forme du verbe devrait être "finir" et non "finir".
# Pour corriger cette erreur, le verbe doit être à la forme -ing, de sorte que la phrase devrait ressembler à ceci : Après avoir terminé, je veux lire "L'appel du coucou".
#
# 4. Choix des mots : le mot "adulte" désigne généralement une personne qui a grandi, alors que le mot "mature" est plus approprié pour décrire un contenu destiné à des adultes ou à des adultes.
# Exemple : "Le roman est destiné à un public adulte en raison de ses thèmes complexes".
#
# Cependant, vous avez répondu efficacement à la question et vos futurs projets de lecture semblent excellents ! Continuez à faire du bon travail.
# Votre phrase comporte quelques petites erreurs d'orthographe et de grammaire. Voici la version corrigée : "Oui, j'ai prévu de lire plus de livres de J.K. Rowling. J'aime beaucoup Harry Potter. Une fois que j'aurai fini, je veux lire 'L'Appel du Coucou'. Il est plus mature, mais j'aime le mystère, alors je pense que ce sera bien pour moi !"
#
# Erreurs identifiées et leurs explications :
# 1. Erreurs d'orthographe : "Rowlling" doit être orthographié "Rowling" et "mistery" doit être orthographié "mystère".
#
# 2. Utilisation de la préposition : La phrase correcte serait "livres de J.K. Rowling", et non "livres de J.K Rowling". Nous utilisons le préposition 'de' pour indiquer l'auteur d'un livre.
# Un exemple de l'utilisation correcte est "Je lis un livre de Stephen King."
#
# 3. Forme de verbe incorrecte : Après 'après', la forme du verbe devrait être 'finir' et non 'fini'.
# Pour corriger cela, le verbe doit être à l'infinitif, donc la phrase devrait ressembler à ceci : "Une fois que j'aurai fini, je veux lire 'L'Appel du Coucou.'"
#
# 4. Choix de mots : Le mot "adulte" se réfère généralement à une personne qui est adulte, tandis que "mature" est un mot plus approprié pour décrire un contenu qui est destiné aux adultes ou aux personnes mûres.
# Exemple : "Le roman est destiné à un public mature en raison de ses thèmes complexes."
#
# Cependant, vous avez répondu efficacement à la question et vos futurs plans de lecture semblent excellents! Continuez le bon travail.
#
# Su frase tiene algunos errores ortográficos y gramaticales menores. Aquí está la versión corregida: "Sí, tengo planes de leer más libros de J.K. Rowling. Me gusta mucho Harry Potter. Cuando termine, quiero leer 'The Cuckoo's Calling'. Es más maduro, pero me gusta el misterio, ¡así que creo que será bueno para mí!".
#
# Errores identificados y sus explicaciones:
# 1. Errores ortográficos: "Rowlling" debe escribirse "Rowling" y "mistery" debe escribirse "mystery".
#
# 2. Uso de la preposición: La frase correcta sería "libros de J.K. Rowling", no "libros de J.K Rowling". Utilizamos la preposición "por" para indicar el autor de un libro.
# Un ejemplo del uso correcto es "Estoy leyendo un libro de Stephen King".
#
# 3. Forma verbal incorrecta: Después de 'after', la forma verbal debería ser 'finishing' y no 'finish'.
# Para solucionarlo, el verbo debe estar en la forma -ing, por lo que la frase debería quedar así: "Después de terminar, quiero leer 'The Cuckoo's Calling'".
#
# 4. Elección de palabras: la palabra "adulto" suele referirse a una persona mayor de edad, mientras que "maduro" es una palabra más apropiada para describir contenidos destinados a adultos o mayores.
# Ejemplo: "La novela está destinada a un público maduro debido a sus temas complejos".
#
# Sin embargo, has respondido eficazmente a la pregunta y tus futuros planes de lectura suenan muy bien. Sigue así.
# Tu oración tiene algunos errores ortográficos y gramaticales menores. Aquí tienes la versión corregida: "Sí, tengo planes de leer más libros de J.K. Rowling. Disfruto mucho de Harry Potter. Después de terminar, quiero leer 'The Cuckoo's Calling'. Es más maduro, pero me gusta el misterio, así que creo que sería bueno para mí!"
#
# Errores identificados y sus explicaciones:
# 1. Errores ortográficos: "Rowlling" se debe escribir como "Rowling" y "mistery" se debe escribir como "misterio".
#
# 2. Uso de preposición: la frase correcta sería "libros de J.K. Rowling", no "libros de J.K Rowling". Usamos la preposición 'de' para indicar el autor de un libro. Un ejemplo del correcto uso es "Estoy leyendo un libro de Stephen King".
#
# 3. Forma del verbo incorrecta: Después de 'después', la forma del verbo debería ser 'terminando' no 'terminar'. Para arreglar esto el verbo necesita estar en la forma -ing, así que la frase debería ser así: "Después de terminar, quiero leer 'The Cuckoo's Calling'."
#
# 4. Elección de palabra: La palabra "adulto" generalmente refiere a una persona que ha crecido, mientras que "maduro" es una palabra más apropiada para describir contenido destinado para adultos. Ejemplo: "La novela está destinada a un público maduro debido a sus temas complejos."
#
# Sin embargo, has respondido eficazmente la pregunta y tus planes de lectura futura suenan geniales! Sigue con el buen trabajo.
# 你的句子基本上是正确的，但需要重新措辞，使之更清晰，语法更恰当。
# 以下是更正后的版本："哈利-波特》是一本非常好的书！它有魔法和冒险，还有许多激动人心的时刻。你一定要读一读，你一定会喜欢的！"
#
# 错误识别与解释：
# 1.Have" 前缺少主语 "it"。
#    主语在英语句子中是必要的。在您的句子中，书（《哈利-波特》）是做动作（拥有魔法和冒险）的主语。
#
# 2.使用不完整短语 "many exciting"。
#     在英语中，形容词（令人兴奋的）通常不能在没有名词的情况下单独存在，除非它是更大句子结构的一部分。我们需要知道什么是 "令人兴奋的"。在这种情况下，"时刻 "或 "部分 "就很合适。
#
# 正确使用 "它 "的例子："冬天经常下雨"。
# 形容词+名词的例子："电影中有许多激动人心的场面"。
# 您的句子大部分是对的，但是为了清晰和正确的语法，需要稍微修改一下。这是修改后的版本："哈利波特是一本非常好的书！它充满了魔法和冒险，还有许多激动人心的时刻。你必须读一读，你会喜欢的！"
#
# 识别的错误和解释：
# 1. 在"Have"之前缺少主语"it"。
#    英语句子中需要主语。在你的例子中，主语是书（哈利波特）正在做动作（有魔法和冒险）。
#
# 2. 使用了不完整的短语"many exciting"。
#     在英语中，形容词（exciting）通常不能单独存在，除非它是更大的句子结构的一部分。我们需要知道什么是'exciting'。在这种情况下，'moments'或'parts'会很合适。
#
# 使用"it"的正确例子："It rains a lot in the winter."
# 形容词 + 名词的例子："There are many exciting scenes in the movie."
# Ihr Satz ist im Großen und Ganzen richtig, könnte aber aus Gründen der Klarheit und der korrekten Grammatik ein wenig umformuliert werden.
# Hier ist die korrigierte Version: "Harry Potter ist ein sehr gutes Buch! Es hat Magie und Abenteuer und viele spannende Momente. Du musst es lesen, du wirst es lieben!"
#
# Identifizierte Fehler und Erklärungen:
# 1. Fehlendes Subjekt "it" vor "Have".
#    Subjekte sind in englischen Sätzen notwendig. In Ihrem Fall ist das Buch (Harry Potter) das Subjekt, das die Handlung ausführt (Magie und Abenteuer erleben).
#
# 2. Verwendung des unvollständigen Satzes "many exciting".
#     Im Englischen kann das Adjektiv (exciting) normalerweise nicht allein ohne ein Substantiv stehen, es sei denn, es ist Teil einer größeren Satzstruktur. Wir müssen wissen, was "aufregend" ist. In diesem Fall würden "Momente" oder "Teile" gut passen.
#
# Beispiel mit richtigem Gebrauch von "es": "Im Winter regnet es viel."
# Beispiel mit Adjektiv + Substantiv: "Es gibt viele spannende Szenen in dem Film."
# Dein Satz ist größtenteils korrekt, aber er könnte ein bisschen umformuliert werden für mehr Klarheit und korrekte Grammatik.
# Hier ist die korrigierte Version: "Harry Potter ist ein sehr gutes Buch! Es hat Magie und Abenteuer und viele aufregende Momente. Du musst es lesen, du wirst es lieben!"
#
# Fehler, die identifiziert und erklärt wurden:
# 1. Fehlendes Subjekt "es" vor "Hat".
#    Subjekte sind notwendig in deutschen Sätzen. In deinem Fall ist das Buch (Harry Potter) das Subjekt, das die Handlung ausführt (hat Magie und Abenteuer).
#
# 2. Die Verwendung der unvollständigen Phrase "viele aufregende".
#     Auf Deutsch kann das Adjektiv (aufregende) normalerweise nicht ohne ein Nomen alleine stehen, es sei denn, es ist Teil einer größeren Satzstruktur. Wir müssen wissen, was 'aufregend' ist. In diesem Fall würden 'Momente' oder 'Teile' gut passen.
#
# Beispiel mit korrekter Verwendung von "es": "Im Winter regnet es viel."
# Beispiel mit einem Adjektiv + Nomen: "Es gibt viele aufregende Szenen in dem Film."
# Votre phrase est en grande partie correcte, mais il faudrait la reformuler pour qu'elle soit plus claire et qu'elle respecte les règles de grammaire.
# Voici la version corrigée : "Harry Potter est un très bon livre ! Il contient de la magie, de l'aventure et de nombreux moments passionnants. Tu dois le lire, tu vas l'adorer !".
#
# Erreurs identifiées et explications :
# 1. Il manque le sujet "it" avant "Have".
#    Les sujets sont nécessaires dans les phrases anglaises. Dans votre cas, le livre (Harry Potter) est le sujet qui fait l'action (avoir de la magie et de l'aventure).
#
# 2. Utilisation de l'expression incomplète "many exciting".
#     En anglais, l'adjectif (exciting) ne peut généralement pas être utilisé seul, sans nom, à moins qu'il ne fasse partie d'une structure de phrase plus large. Nous devons savoir ce qui est "excitant". Dans ce cas, "moments" ou "parties" conviendraient parfaitement.
#
# Exemple avec l'utilisation correcte de "it" : "Il pleut beaucoup en hiver.
# Exemple avec un adjectif + un nom : "Il y a beaucoup de scènes passionnantes dans le film".
# Votre phrase est principalement correcte, mais elle pourrait être légèrement reformulée pour plus de clarté et une grammaire appropriée.
# Voici la version corrigée : "Harry Potter est un très bon livre ! Il contient de la magie et de l'aventure, ainsi que de nombreux moments passionnants. Vous devez le lire, vous l'adorerez !"
#
# Erreurs identifiées et explications:
# 1. Sujet manquant "il" avant "A".
#    Les sujets sont nécessaires dans les phrases en français. Dans votre cas, le livre (Harry Potter) est le sujet qui fait l'action (avoir de la magie et de l'aventure).
#
# 2. Utilisation de la phrase incomplète "beaucoup d'excitant".
#     En français, l'adjectif (excitant) ne peut généralement pas se tenir seul sans un nom, sauf s'il fait partie d'une structure de phrase plus grande. Nous avons besoin de savoir ce qui est 'excitant'. Dans ce cas, 'moments' ou 'parties' conviendraient bien.
#
# Exemple avec l'utilisation correcte de "il" : "Il pleut beaucoup en hiver."
# Exemple avec un adjectif + nom : "Il y a beaucoup de scènes passionnantes dans le film."
# La frase es correcta en su mayor parte, pero habría que reformularla un poco para que sea más clara y gramaticalmente correcta.
# Aquí tienes la versión corregida: "Harry Potter es un libro muy bueno. Tiene magia y aventuras, y muchos momentos emocionantes. Debes leerlo, ¡te encantará!".
#
# Errores identificados y explicaciones:
# 1. Falta el sujeto "it" antes de "Have".
#    Los sujetos son necesarios en las frases en inglés. En tu caso, el libro (Harry Potter) es el sujeto que realiza la acción (tener magia y aventuras).
#
# 2. Usar la frase incompleta "many exciting".
#     En inglés, el adjetivo (exciting) normalmente no puede estar solo sin un sustantivo a menos que forme parte de una estructura oracional más amplia. Necesitamos saber qué es "exciting". En este caso, "momentos" o "partes" encajarían bien.
#
# Ejemplo con el uso correcto de "it": "Llueve mucho en invierno".
# Ejemplo con adjetivo + sustantivo: "Hay muchas escenas emocionantes en la película".
# ...
# C'est une excellente question ! Tu te débrouilles très bien ! Maintenant, imagine que tu commandes ta pizza préférée par téléphone, comment le ferais-tu ? N'oublie pas d'être poli et clair.
# ¡Qué buena pregunta! ¡Lo estás haciendo muy bien! Ahora, imagina que pides tu pizza favorita por teléfono, ¿cómo lo harías? Recuerda ser educado y claro.
# ¡Esa es una gran pregunta! ¡Lo estás haciendo muy bien! Ahora, imagina que estás pidiendo tu pizza favorita por teléfono, ¿cómo lo harías? Recuerda ser educado y claro.
# 棒极了你已经掌握了订披萨的技巧！现在，你能描述一下你最喜欢的品牌标志的颜色、大小和形状吗？这将帮助你练习描述物体。
# 太棒了！你已经掌握了订购比萨的技巧！现在，你能描述一下你最喜欢的品牌logo的颜色、大小和形状吗？这将帮助你练习描述物品。
# Wahnsinn! Du hast die Pizzabestellung gemeistert! Kannst du mir jetzt die Farbe, Größe und Form des Logos deiner Lieblingsmarke beschreiben? So kannst du das Beschreiben von Gegenständen üben.
# Großartig! Sie haben das Bestellen von Pizza gemeistert! Können Sie nun die Farbe, Größe und Form des Logos Ihrer Lieblingsmarke beschreiben? Dies wird Ihnen helfen, das Beschreiben von Objekten zu üben.
# Génial ! Vous avez maîtrisé la commande de pizzas ! Maintenant, pouvez-vous me décrire la couleur, la taille et la forme du logo de votre marque préférée ? Cela vous aidera à vous entraîner à décrire des objets.
# Génial! Vous avez maîtrisé la commande de pizza! Maintenant, pouvez-vous me décrire la couleur, la taille et la forme du logo de votre marque préférée? Cela vous aidera à vous entraîner à décrire des objets.
# ¡Impresionante! ¡Ya dominas el pedido de pizza! Ahora, ¿puedes describirme el color, el tamaño y la forma del logotipo de tu marca favorita? Esto te ayudará a practicar la descripción de objetos.
# ¡Genial! ¡Has dominado el pedido de pizza! Ahora, ¿puedes describirme el color, el tamaño y la forma del logotipo de tu marca favorita? Esto te ayudará a practicar la descripción de objetos.
# 当然！欢迎来到令人兴奋的英语学习世界！ 😊 首先，我们为什么不练习一下自我介绍呢？你能介绍一下你自己吗，比如你来自哪里，最喜欢的爱好是什么？
# 当然！欢迎来到学习英语的激动人心的世界！ 😊首先，我们为何不来练习一下自我介绍？你能告诉我一些关于你自己的信息吗，比如你来自哪里，你最喜欢的爱好是什么？
# Ja, natürlich! Willkommen in der aufregenden Welt des Englischlernens! 😊 Warum üben wir nicht erst einmal, uns vorzustellen? Kannst du mir etwas über dich erzählen, zum Beispiel woher du kommst und was deine Lieblingshobbys sind?
# Natürlich! Willkommen in der aufregenden Welt des Englischlernens! 😊 Zum Anfang, warum üben wir nicht die Vorstellungen? Können Sie mir ein bisschen über sich selbst erzählen, wie zum Beispiel woher Sie kommen und was Ihre Lieblingshobbys sind?
# Bien sûr ! Bienvenue dans le monde passionnant de l'apprentissage de l'anglais ! 😊 Pour commencer, pourquoi ne pas pratiquer les présentations ? Pouvez-vous me parler un peu de vous, par exemple d'où vous venez et quels sont vos passe-temps favoris ?
# Bien sûr ! Bienvenue dans le monde passionnant de l'apprentissage de l'anglais ! 😊 Pour commencer, pourquoi ne pas pratiquer les présentations ? Pouvez-vous me parler un peu de vous, comme d'où vous venez et quels sont vos passe-temps préférés ?
# ¡¡¡Por supuesto!!! Bienvenido al apasionante mundo de aprender inglés! 😊 Para empezar, ¿por qué no practicamos las presentaciones? Puedes hablarme un poco de ti, como de dónde eres y cuáles son tus aficiones favoritas?
# ¡Por supuesto! ¡Bienvenido al emocionante mundo de aprender inglés! 😊 Para comenzar, ¿por qué no practicamos las presentaciones? ¿Puedes contarme un poco sobre ti, como de dónde eres y cuáles son tus pasatiempos favoritos?
# That's great！📚⚽️ 阅读书籍是学习英语的绝佳途径。告诉我，你喜欢读什么样的书？小说？非小说类？你最喜欢哪些书？
#
# 太棒了！📚⚽️ 阅读书籍是学习英语的极好方式。告诉我，你喜欢阅读什么类型的书籍？小说？ 非小说？你最喜欢的一些书籍是什么？
# Das ist großartig! 📚⚽️ Bücher zu lesen ist eine hervorragende Möglichkeit, Englisch zu lernen. Sagen Sie mir, welche Art von Büchern lesen Sie gerne? Belletristik? Sachbücher? Was sind einige deiner Lieblingsbücher?
#
# Das ist großartig! 📚⚽️ Bücher zu lesen ist eine hervorragende Möglichkeit, Englisch zu lernen. Sag mal, welche Art von Büchern liest du gerne? Belletristik? Sachbücher? Was sind einige deiner Lieblingsbücher?
# C'est génial ! 📚⚽️ La lecture de livres est un excellent moyen d'apprendre l'anglais. Dis-moi, quel genre de livres aimes-tu lire ? Des romans ? Des ouvrages non fictionnels ? Quels sont vos livres préférés ?
#
# C'est génial! 📚⚽️ Lire des livres est un excellent moyen d'apprendre l'anglais. Dis-moi, quels types de livres aimes-tu lire? Fiction? Non-fiction? Quels sont certains de tes livres préférés?
# ¡Qué bien! 📚⚽️ Leer libros es una forma excelente de aprender inglés. Dime, ¿qué tipo de libros te gusta leer? ¿De ficción? ¿De no ficción? ¿Cuáles son tus libros favoritos?
#
# ¡Eso es genial! 📚⚽️ Leer libros es una excelente manera de aprender inglés. Dime, ¿qué tipo de libros disfrutas leyendo? ¿Ficción? ¿No ficción? ¿Cuáles son algunos de tus libros favoritos?
# 太棒了🧙‍♂️ 《哈利-波特》系列风靡全球。你能用自己的话描述《哈利-波特》中的一个人物吗？记住要包括他们的外貌、性格或与他们有关的任何有趣事件。
# 太棒了！🧙‍♂️哈利波特系列在全球都很受欢迎。你能用自己的话描述一下哈利波特里的一个角色吗？记得包括他们的外貌、性格或与他们相关的有趣事件。
# Fantastisch! 🧙‍♂️ Die Harry Potter-Reihe ist weltweit beliebt. Kannst du eine der Figuren aus Harry Potter in deinen eigenen Worten beschreiben? Denken Sie daran, ihr Aussehen, ihre Persönlichkeit oder interessante Ereignisse, die mit ihnen verbunden sind, zu erwähnen.
# Fantastisch! 🧙‍♂️ Die Harry Potter Serie ist weltweit beliebt. Können Sie einen der Charaktere aus Harry Potter mit Ihren eigenen Worten beschreiben? Denken Sie daran, ihr Aussehen, ihre Persönlichkeit oder interessante Ereignisse, die mit ihnen in Zusammenhang stehen, zu erwähnen.
# Fantastique ! 🧙‍♂️ La série Harry Potter est populaire dans le monde entier. Pouvez-vous décrire l'un des personnages de Harry Potter avec vos propres mots ? N'oubliez pas d'inclure leur apparence, leur personnalité ou tout événement intéressant qui leur est associé.
# Fantastique! 🧙‍♂️ La série Harry Potter est populaire dans le monde entier. Pouvez-vous décrire l'un des personnages de Harry Potter avec vos propres mots? N'oubliez pas d'inclure leur apparence, leur personnalité ou tout événement intéressant associé à eux.
# ¡Fantástico! 🧙‍♂️ La serie Harry Potter es popular en todo el mundo. ¿Puedes describir con tus propias palabras a uno de los personajes de Harry Potter? Recuerda incluir su aspecto, personalidad o cualquier acontecimiento interesante relacionado con ellos.
# ¡Fantástico! 🧙‍♂️ La serie de Harry Potter es popular en todo el mundo. ¿Puedes describir en tus propias palabras a uno de los personajes de Harry Potter? Recuerda incluir su apariencia, personalidad o cualquier evento interesante asociado con ellos.
# 做得好！😊 赫敏确实是一个标志性人物。现在，我们来用过去时，它用于表示过去完成的动作。你能告诉我昨天你踢或看的足球比赛发生了什么吗？
# 做得好！😊 赫敏确实是一个标志性的角色。现在，让我们使用一般过去时，这用于表示过去已经完成的动作。你能告诉我昨天你参加或者观看的足球比赛中发生了什么吗？
# Gut gemacht! 😊 Hermine ist in der Tat eine ikonische Figur. Jetzt verwenden wir das Past Simple, das für Handlungen verwendet wird, die in der Vergangenheit liegen. Kannst du mir sagen, was bei dem gestrigen Fußballspiel, das du gespielt oder gesehen hast, passiert ist?
# Gut gemacht! 😊 Hermione ist in der Tat eine ikonische Figur. Jetzt verwenden wir das Präteritum, das für Handlungen verwendet wird, die in der Vergangenheit abgeschlossen wurden. Kannst du mir sagen, was in dem Fußballspiel passiert ist, das du gestern gespielt oder gesehen hast?
# Bien joué ! 😊 Hermione est en effet un personnage emblématique. Maintenant, utilisons le passé simple, qui est utilisé pour les actions accomplies dans le passé. Pouvez-vous me dire ce qui s'est passé dans le match de football d'hier que vous avez joué ou regardé ?
# Bien fait! 😊 Hermione est en effet un personnage emblématique. Maintenant, utilisons le passé simple, qui est utilisé pour des actions complétées dans le passé. Pouvez-vous me dire ce qui s'est passé lors du match de football d'hier que vous avez joué ou regardé?
# Hermione es un personaje emblemático. Ahora, usemos el tiempo pasado simple, que se usa para acciones completadas en el pasado. Puedes decirme qué pasó en el partido de fútbol de ayer que jugaste o viste?
# ¡Bien hecho! 😊 Hermione es en efecto un personaje icónico. Ahora, usemos el tiempo pasado simple, que se usa para acciones completadas en el pasado. ¿Puedes decirme qué sucedió en el partido de fútbol de ayer que jugaste o viste?
# 干得好！⚽️ 现在，让我们换个话题，练习有礼貌地提出请求和要求。你能借我一本书吗？试着使用 "Could you... "或 "Would you mind... "这样的短语。
# 做得好！⚽️ 现在，让我们转换一下方向，练习礼貌地提出请求和询问事情。你能用英语向我借一本书吗？试试像"你能......"或者"你会介意......"这样的短语。
# Gut gemacht!⚽️ Jetzt wollen wir einen anderen Gang einlegen und üben, höflich um etwas zu bitten und zu bitten. Können Sie mich bitten, Ihnen ein Buch auf Englisch zu leihen? Versuchen Sie es mit Sätzen wie "Could you..." oder "Would you mind...".
# Gut gemacht! ⚽️ Jetzt wechseln wir den Gang und üben höflich Anfragen und um Dinge zu bitten. Könntest du mich bitten, dir ein Buch auf Englisch zu leihen? Versuche Phrasen wie "Könntest du..." oder "Würde es dir etwas ausmachen...".
# Bravo!⚽️ Maintenant, passons à la vitesse supérieure et exerçons-nous à faire des demandes et à demander des choses poliment. Pouvez-vous me demander de vous prêter un livre en anglais ? Essayez d'utiliser des phrases comme "Could you..." ou "Would you mind...".
# Très bien !⚽️ Maintenant, changeons de vitesse et pratiquons à faire des demandes et à demander des choses poliment. Pouvez-vous me demander de vous prêter un livre en anglais ? Essayez d'utiliser des expressions comme "Pourriez-vous..." ou "Cela vous dérangerait-il...".
# Bien hecho!⚽️ Ahora, cambiemos de marcha y practiquemos hacer peticiones y pedir cosas educadamente. ¿Puedes pedirme que te preste un libro en inglés? Intenta utilizar frases como "Could you..." o "Would you mind...".
# ¡Bien hecho!⚽️ Ahora, cambiemos de tema y practiquemos haciendo solicitudes y pidiendo cosas educadamente. ¿Podrías pedirme que te preste un libro en inglés? Intenta usar frases como "¿Podrías..." o "¿Te importaría...".
# 干得好好极了！现在，让我们用一下条件式，特别是第二个条件式。它用于谈论想象中的情况，通常是那些可能永远不会发生的事情。例如，"如果我中了彩票，我会买一栋房子"你能告诉我，如果你能见到《哈利-波特》的作者 JK 罗琳，你会做什么吗？
# 做得好！📚 好极了！现在，让我们来用一些条件句，特别是第二类条件句。这种句型用于谈论想象的情况，通常是可能永远不会发生的事情。例如，“如果我中了彩票，我会买一座房子。”你能告诉我如果你能见到哈利波特的作者JK罗琳，你会做什么吗？
# Gut gemacht! 📚 Sehr gut! Nun zu den Konditionalen, insbesondere dem zweiten Konditional. Es wird verwendet, um über imaginäre Situationen zu sprechen, normalerweise über Dinge, die niemals eintreten werden. Zum Beispiel: "Wenn ich im Lotto gewinnen würde, würde ich ein Haus kaufen." Kannst du mir sagen, was du tun würdest, wenn du JK Rowling, die Autorin von Harry Potter, treffen könntest?
# Gut gemacht! 📚 Sehr gut! Jetzt verwenden wir ein bisschen Konditionale, speziell die zweite Konditional. Sie wird verwendet, um sich vorgestellte Situationen vorzustellen, normalerweise Dinge, die vielleicht nie passieren werden. Zum Beispiel: "Wenn ich im Lotto gewinnen würde, würde ich ein Haus kaufen." Können Sie mir sagen, was Sie tun würden, wenn Sie JK Rowling, die Autorin von Harry Potter, treffen könnten?
# Bien joué ! 📚 Jolly good ! Maintenant, utilisons un peu de conditionnel, en particulier le deuxième conditionnel. Il est utilisé pour parler de situations imaginées, généralement des choses qui ne se produiront peut-être jamais. Par exemple, "Si je gagnais à la loterie, j'achèterais une maison". Pouvez-vous me dire ce que vous feriez si vous pouviez rencontrer JK Rowling, l'auteur de Harry Potter ?
# Très bien fait! 📚 Vraiment bon! Maintenant, utilisons un peu de conditionnel, spécifiquement le second conditionnel. Il est utilisé pour parler de situations imaginées, généralement des choses qui pourraient ne jamais arriver. Par exemple, "Si je gagnais à la loterie, j'achèterais une maison." Pouvez-vous me dire ce que vous feriez si vous pouviez rencontrer JK Rowling, l'auteure de Harry Potter?
# ¡Bien hecho! 📚 ¡Muy bien! Ahora, vamos a usar un poco los condicionales, concretamente el segundo condicional. Se usa para hablar de situaciones imaginarias, normalmente cosas que quizá nunca ocurran. Por ejemplo: "Si me tocara la lotería, me compraría una casa". ¿Puedes decirme qué harías si pudieras conocer a JK Rowling, la autora de Harry Potter?
# ¡Bien hecho! 📚 ¡Muy bien! Ahora, usemos un poco de condicionales, específicamente el segundo condicional. Se utiliza para hablar de situaciones imaginadas, generalmente cosas que podrían nunca suceder. Por ejemplo, "Si ganara la lotería, compraría una casa". ¿Puedes decirme qué harías si pudieras conocer a JK Rowling, la autora de Harry Potter?
# 精彩回答！💫现在，让我们来关注描述性语言。你能用形容词描述你的家乡日本吗？试着用一些词语来描述这个地方的景色、声音甚至感觉。
# 太棒的回应了！💫现在，让我们专注于描述性的语言。你可以用形容词来描述你的祖国日本吗？试着使用一些能描述这个地方的视觉、听觉或甚至触觉的词汇。
# Fantastische Antwort! 💫 Jetzt wollen wir uns auf die beschreibende Sprache konzentrieren. Kannst du Japan, dein Heimatland, mit Adjektiven beschreiben? Versuche, Wörter zu verwenden, die den Anblick, den Klang oder sogar das Gefühl des Ortes beschreiben.
# Fantastische Antwort! 💫 Jetzt konzentrieren wir uns auf beschreibende Sprache. Können Sie Japan, Ihr Heimatland, mit Adjektiven beschreiben? Versuchen Sie, Wörter zu verwenden, die die Sehenswürdigkeiten, Geräusche oder sogar das Gefühl des Ortes beschreiben.
# Excellente réponse ! 💫 Concentrons-nous maintenant sur le langage descriptif. Pouvez-vous décrire le Japon, votre pays d'origine, à l'aide d'adjectifs ? Essayez d'utiliser des mots qui décrivent la vue, le son ou même la sensation de l'endroit.
# Réponse fantastique! 💫 Maintenant, concentrons-nous sur le langage descriptif. Pouvez-vous décrire le Japon, votre patrie, en utilisant des adjectifs? Essayez d'utiliser des mots qui décrivent les vues, les sons, ou même l'ambiance du lieu.
# ¡Fantástica respuesta! 💫 Ahora, centrémonos en el lenguaje descriptivo. Puedes describir Japón, tu tierra natal, utilizando adjetivos? Intenta utilizar palabras que describan las vistas, el sonido o incluso la sensación del lugar.
# ¡Fantástica respuesta! 💫 Ahora, centrémonos en el lenguaje descriptivo. ¿Podrías describir Japón, tu tierra natal, usando adjetivos? Intenta usar palabras que describan las vistas, los sonidos o incluso la sensación del lugar.
# 干得好🇯🇵 对日本的描述非常精彩。下面我们来练习一下介词 "地点 "和 "方向 "的用法。您能带我参观一下您的房子吗？尝试使用 "在"、"上"、"在"、"穿过"、"通过 "等介词。
# 干得好！🇯🇵 这是对日本的非常好的描述。让我们继续练习使用地点和方向的介词。你能像我从未到过你家一样，带我参观一下你的房子吗？尝试使用像“在”，“上”，“在”，“穿过”，“通过”等介词。
# Gut gemacht! 🇯🇵 Das ist eine wirklich schöne Beschreibung von Japan. Üben wir nun die Verwendung von Orts- und Richtungspräpositionen. Könnten Sie mich durch Ihr Haus führen, als ob ich noch nie dort gewesen wäre? Versuchen Sie, Präpositionen wie "in", "auf", "bei", "quer", "durch" usw. zu verwenden.
# Gut gemacht! 🇯🇵 Das ist eine wirklich schöne Beschreibung von Japan. Lassen Sie uns nun mit der Übung zur Verwendung von Präpositionen des Ortes und der Richtung fortfahren. Könnten Sie mich durch Ihr Haus führen, als ob ich noch nie dort gewesen wäre? Versuchen Sie, Präpositionen wie 'in', 'auf', 'an', 'über', 'durch', usw. zu verwenden.
# Bravo ! 🇯🇵 C'est une très belle description du Japon. Passons maintenant à la pratique de l'utilisation des prépositions de lieu et de direction. Pourriez-vous me guider dans votre maison comme si je n'y étais jamais allé auparavant ? Essayez d'utiliser des prépositions comme "in", "on", "at", "across", "through", etc.
# Bien joué ! 🇯🇵 C'est une très belle description du Japon. Passons maintenant à la pratique de l'utilisation des prépositions de lieu et de direction. Pourriez-vous me guider à travers votre maison comme si je n'y étais jamais allé auparavant ? Essayez d'utiliser des prépositions comme 'dans', 'sur', 'à', 'à travers', 'par', etc.
# Bien hecho. 🇯🇵 Es una descripción muy bonita de Japón. Pasemos a practicar el uso de las preposiciones de lugar y dirección. ¿Podrías guiarme por tu casa como si nunca hubiera estado allí? Intenta utilizar preposiciones como "en", "sobre", "en", "a través de", "por", etc.
# ¡Bien hecho! 🇯🇵 Esa es una descripción realmente bonita de Japón. Pasemos a practicar el uso de las preposiciones de lugar y dirección. ¿Podrías guiarme a través de tu casa como si nunca hubiera estado allí antes? Intenta usar preposiciones como 'en', 'sobre', 'en', 'a través de', 'por', etc.

# %% [markdown]
# ## Section3 Calculate the BLEU Score

# %%
import pandas as pd
import nltk
from nltk.translate.bleu_score import sentence_bleu
from nltk.tokenize import word_tokenize
import numpy as np

# Downloading the Punkt tokenizer models (used for nltk word tokenization)
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# #### note: since the tokenization for chinese is different, BLEU score calculations rely heavily on correct tokenization of both the reference and the candidate text. Chinese, unlike languages using the Latin alphabet, does not use spaces to separate words. This means standard tokenization methods (like the one used in the nltk library) can not work correctly. So we use the jieba as our tokenizer.

# %%
import jieba

# %%
def tokenize_chinese(text):
    return list(jieba.cut(text))

# Example usage
chinese_text = "你好世界"
tokens = tokenize_chinese(chinese_text)
print(tokens)  # ['你好', '世界']
# Out:
# Building prefix dict from the default dictionary ...
# DEBUG:jieba:Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# DEBUG:jieba:Dumping model to file cache /tmp/jieba.cache
# Loading model cost 1.297 seconds.
# DEBUG:jieba:Loading model cost 1.297 seconds.
# Prefix dict has been built successfully.
# DEBUG:jieba:Prefix dict has been built successfully.
# ['你好', '世界']

# %%
# Add columns for BLEU scores
for lang in languages:
    df[f'BLEU_Score_{lang}'] = np.nan

for index, row in df.iterrows():
    for lang in languages:
        if lang == 'Chinese':
            # Use jieba for Chinese tokenization
            reference = tokenize_chinese(row[f'Deepl_Translation_{lang}'])
            candidate = tokenize_chinese(row[f'OpenAI_Translation_{lang}'])
        else:
            # Use NLTK tokenizer for other languages
            reference = word_tokenize(row[f'Deepl_Translation_{lang}'].lower())
            candidate = word_tokenize(row[f'OpenAI_Translation_{lang}'].lower())

        # Calculating BLEU score
        bleu_score = sentence_bleu([reference], candidate, weights=(0.25, 0.25, 0.25, 0.25))
        df.at[index, f'BLEU_Score_{lang}'] = bleu_score
# Out:
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %%
# Optionally, save to a new CSV
df.to_csv('bleu_scores.csv', index=False)

# %% [markdown]
# ### Calculate the average BLEU score

# %%
# Continue from the previous script

languages = ['Chinese', 'German', 'French', 'Spanish']

# Dictionary to store the average BLEU scores
average_bleu_scores = {}

for lang in languages:
    # Calculate the average BLEU score for each language
    average_score = df[f'BLEU_Score_{lang}'].mean()
    average_bleu_scores[lang] = average_score

# Convert the dictionary to a DataFrame for display
average_bleu_df = pd.DataFrame(list(average_bleu_scores.items()), columns=['Language', 'Average_BLEU_Score'])

# Display the average BLEU score table
print(average_bleu_df)
# Out:
#   Language  Average_BLEU_Score
# 0  Chinese            0.380189
# 1   German            0.529708
# 2   French            0.617482
# 3  Spanish            0.584771
